# %% [markdown]
# # News Query & Summary App using LLM

# %% [markdown]
# Load necessary packages.

# %%
import cohere
import json
from datetime import date
import requests
from fpdf import FPDF
from fpdf.enums import XPos, YPos
from io import BytesIO
# Out:
# /Users/timonweidemann/.pyenv/versions/3.10.15/lib/python3.10/site-packages/fpdf/__init__.py:40: UserWarning: You have both PyFPDF & fpdf2 installed. Both packages cannot be installed at the same time as they share the same module namespace. To only keep fpdf2, run: pip uninstall --yes pypdf && pip install --upgrade fpdf2
#   warnings.warn(

# %% [markdown]
# Define test prompt.

# %%
test_prompt = "What's happening in Egypt right now?"

# %% [markdown]
# Create prompt to GDELT parameter transformation.

# %%
def get_gdelt_params(user_prompt):

    # Initialize Cohere client
    with open("key.txt") as f:
        COHERE_API_KEY = f.read()
    cohere_client = cohere.ClientV2(COHERE_API_KEY)

    # Save the date for today
    today = date.today().strftime("%Y%m%d")

    # Define the system parameters
    system_prompt = f"""
    The user will write a text asking for news about a topic during a period.
    Extract the information necessary to populate this json object:
    {{
    "query": X,
    "startdate": X,
    "enddate": X
    }}
    The query should include a certain action (e.g. "terror" or "protest") and region (e.g. "france" or "paris"). It is intended for the GDELT API.
    The startdate and enddate should be in the format YYYYMMDD. Remember that today is {today}.
    If the information is not present, return "N/A".
    Respond only with the json object.
    """

    # Check if model input is string
    if not isinstance(user_prompt, str):
        user_prompt = str(user_prompt)

    # Get the model response
    raw_response = cohere_client.chat(
        messages = [
        {
            'role': 'system',
            'content': system_prompt  
        }, 
        {
            'role': 'user',
            'content': user_prompt
        }
        ],
        model='command-r-plus'
    )

    # Save the response
    response_text = raw_response.message.content[0].text

    # Check if response format is correct
    if '```json\n' in response_text:
        response_text_clean = response_text.split('```json\n')[1].split('\n```')[0].strip()
        try:
            response_json = json.loads(response_text_clean)
        except Exception:
            return response_text_clean
    else:
        try:
            response_json = json.loads(response_text)
        except Exception:
            return response_text
    
    # Check if the response JSON contains N/A's
    if response_json['query'] == "N/A":
        return "Query not found"
    if response_json['startdate'] == "N/A" and response_json['enddate'] == "N/A":
        response_json['enddate'] = str(int(today) - 1)
        response_json['startdate'] = str(int(response_json['enddate']) - 7)
    if response_json['startdate'] == "N/A":
        response_json['startdate'] = str(int(response_json['enddate']) - 7)
    if response_json['enddate'] == "N/A":
        response_json['enddate'] = str(int(today) - 1)

    # Check if the response JSON dates are valid
    if response_json['enddate'] == today:
        response_json['enddate'] = str(int(today) - 1)
    if int(response_json['enddate']) < int(response_json['startdate']):
        response_json['startdate'] = str(int(response_json['enddate']) - 7)

    # Return the response
    response = response_json
    return response

# %% [markdown]
# Test transformation.

# %%
test_params = get_gdelt_params(test_prompt)
test_params
# Out:
# {'query': 'egypt', 'startdate': '20250322', 'enddate': '20250329'}

# %% [markdown]
# Create GDELT parameter to GDELT articles query.

# %%
def get_gdelt_articles(gdelt_params):

    # Extract variables parameters
    query = gdelt_params['query']
    startdate = gdelt_params['startdate']
    enddate = gdelt_params['enddate']

    # Save API attributes
    url = "https://api.gdeltproject.org/api/v2/doc/doc"
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/115.0.0.0 Safari/537.36"
        )
    }

    # Save API parameters
    params = {
        "query": f"{query}",
        "startdatetime": f"{startdate}000000",
        "enddatetime": f"{enddate}000000",
        "mode": "artlist",
        "format": "json",
        "maxrecords": 50,
        "sort": "hybridrel"
    }

    # Get the API response
    raw_response = requests.get(url, params=params, headers=headers)

    # Check if API call is working and response format is valid and return the response
    if raw_response.status_code == 200:
        try:
            response = json.loads(raw_response.text)
        except Exception:
            response = raw_response.text
        return response
    else:
        return raw_response.status_code

# %% [markdown]
# Test query.

# %%
test_articles = get_gdelt_articles(test_params)
test_articles
# Out:
# {'articles': [{'url': 'https://news.republika.co.id/berita/stideo451/mesir-bantah-akan-relokasi-warga-palestina-ke-sinai-utara',
#    'url_mobile': '',
#    'title': 'Mesir Bantah akan Relokasi Warga Palestina ke Sinai Utara',
#    'seendate': '20250322T073000Z',
#    'socialimage': 'https://static.republika.co.id/uploads/images/inpicture_slide/_250305044500-609.png',
#    'domain': 'news.republika.co.id',
#    'language': 'Indonesian',
#    'sourcecountry': 'Indonesia'},
#   {'url': 'http://www.misr5.com/uncategorized/1694.html',
#    'url_mobile': '',
#    'title': 'مصر ضد سيراليون .. موعد المباراة والقنوات الناقلة والتشكيل وترتيب المجموعة',
#    'seendate': '20250324T203000Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-24-8f0c0a9f26.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/2371.html',
#    'url_mobile': '',
#    'title': 'فنان شاب .. تعرف على ضيف الحلقة 25 من برنامج رامز إيلون مصر',
#    'seendate': '20250325T161500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-25-aeec2bc055.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.inn.co.il/news/664670',
#    'url_mobile': '',
#    'title': '  הצעה אחרונה  למצרים לקבל עזתים',
#    'seendate': '20250324T081500Z',
#    'socialimage': 'https://2.a7.org/files/pictures/000/1176841.jpg',
#    'domain': 'inn.co.il',
#    'language': 'Hebrew',
#    'sourcecountry': 'Israel'},
#   {'url': 'https://www.vetogate.com/5374298',
#    'url_mobile': '',
#    'title': 'موعد مباراة منتخب مصر أمام سيراليون في تصفيات كأس العالم والقنوات الناقلة',
#    'seendate': '20250323T080000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.ynet.co.il/news/article/yokra14309834',
#    'url_mobile': '',
#    'title': '46 שנה להסכם עם מצרים : שלום קריר',
#    'seendate': '20250326T000000Z',
#    'socialimage': 'https://ynet-pic1.yit.co.il/picserver6/crop_images/2025/01/01/BJtRK1fUye/BJtRK1fUye_0_0_2998_1962_0_large.jpg',
#    'domain': 'ynet.co.il',
#    'language': 'Hebrew',
#    'sourcecountry': 'Israel'},
#   {'url': 'https://www.vetogate.com/5374972',
#    'url_mobile': '',
#    'title': 'منتخب مصر يواصل استعداداته لمواجهة سيراليون بتصفيات كأس العالم ( صور ) ',
#    'seendate': '20250324T003000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://time.mk/c/dda01bda4c/otkriena-e-grobnica-na-neidentifikuvan-anticki-egipetski-faraon.html',
#    'url_mobile': '',
#    'title': 'Откриена е гробница на неидентификуван антички египетски фараон',
#    'seendate': '20250328T180000Z',
#    'socialimage': 'https://mkd.mk/wp-content/uploads/2025/03/grobnici-na-faraoni-egipet-unsplash-scaled.jpg',
#    'domain': 'time.mk',
#    'language': 'Macedonian',
#    'sourcecountry': 'Macedonia'},
#   {'url': 'https://www.dostor.org/5013055',
#    'url_mobile': '',
#    'title': 'مشاهدة مباراة مصر وسيراليون في تصفيات مونديال 2026 .. بث مباشر الآن ( فيديو ) ',
#    'seendate': '20250325T191500Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.cna.com.tw:443/news/aloc/202503270214.aspx',
#    'url_mobile': '',
#    'title': '移除埃及聖䴉 林保署熱區設誘引站假鳥吸引群聚 | 地方',
#    'seendate': '20250327T090000Z',
#    'socialimage': 'https://imgcdn.cna.com.tw/www/WebPhotos/1024/20250327/1152x768_wmkn_0_C20250327000119.jpg',
#    'domain': 'cna.com.tw',
#    'language': 'Chinese',
#    'sourcecountry': 'Taiwan'},
#   {'url': 'https://www.vetogate.com/5376219',
#    'url_mobile': '',
#    'title': 'ترتيب مجموعة مصر في تصفيات كأس العالم بعد الفوز على سيراليون',
#    'seendate': '20250325T221500Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5016058',
#    'url_mobile': '',
#    'title': 'هتافات بعض صحفيى مصر فى الميزان ! ',
#    'seendate': '20250328T110000Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/282.html',
#    'url_mobile': '',
#    'title': 'جبالي يحيل قرارات باتفاقيات دولية إلى لجنة الشئون الدستورية والتشريعية',
#    'seendate': '20250323T104500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-764d30640b.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/217.html',
#    'url_mobile': '',
#    'title': 'رئيس النواب يحيل 7 اتفاقيات دولية ومشروعي قانونين إلى اللجان النوعية',
#    'seendate': '20250323T094500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-1304142148.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/1862.html',
#    'url_mobile': '',
#    'title': 'موعد مباراة منتخب مصر وسيراليون في تصفيات أفريقيا المؤهلة لكأس العالم 2026 والقنوات الناقلة والتشكيل المتوقع',
#    'seendate': '20250325T081500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-25-781e160575.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/2330.html',
#    'url_mobile': '',
#    'title': 'آخر تحديث .. سعر الدولار مقابل الجنيه المصري اليوم الثلاثاء 25 - 3 - 2025',
#    'seendate': '20250325T153000Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-25-810b17301b.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/301.html',
#    'url_mobile': '',
#    'title': 'أسعار البنزين والسولار اليوم الأحد 23 مارس 2025',
#    'seendate': '20250323T104500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-cb2a152f18.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/5.html',
#    'url_mobile': '',
#    'title': 'الفنان أحمد سعد يحيي حفلتين لصالح راعي مصر في استراليا ١٦و ١٧ مايو المقبل',
#    'seendate': '20250323T040000Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-b7000f8608.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.shorouknews.com/news/view.aspx?cdate=23032025&id=f8af6df7-d9ef-46d7-8696-0597b06ba29c',
#    'url_mobile': '',
#    'title': 'مجلس النواب يُحيل تعديلات أحكام قانون المرور للجان المختصة',
#    'seendate': '20250323T100000Z',
#    'socialimage': 'https://www.shorouknews.com/uploadedimages/Sections/Egypt/original/%D9%85%D8%AC%D9%84%D8%B3%20%D8%A7%D9%84%D9%86%D9%88%D8%A7%D8%A8%20%D8%AD%D9%86%D9%81%D9%8A%20%D8%A7%D9%84%D8%AC%D8%A8%D8%A7%D9%84%D9%8A%20%D9%84%D8%AC%D9%86%D8%A9.jpg',
#    'domain': 'shorouknews.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/1011.html',
#    'url_mobile': '',
#    'title': 'أحمد عيد عبدالملك : استبعاد إمام عاشور من منتخب مصر ليس فني',
#    'seendate': '20250324T081500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-24-31e9e4103d.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5374679',
#    'url_mobile': '',
#    'title': 'قلق في بيراميدز بعد إصابة إبراهيم عادل',
#    'seendate': '20250323T144500Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://world.people.com.cn/n1/2025/0327/c1002-40448243.html',
#    'url_mobile': '',
#    'title': '中企捐赠教学设备 助力埃及中文教育 -- 国际 -- 人民网',
#    'seendate': '20250327T134500Z',
#    'socialimage': '',
#    'domain': 'world.people.com.cn',
#    'language': 'Chinese',
#    'sourcecountry': 'China'},
#   {'url': 'https://www.dostor.org/5013609',
#    'url_mobile': '',
#    'title': 'ترتيب مجموعة مصر في تصفيات كأس العالم 2026',
#    'seendate': '20250326T083000Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5012841',
#    'url_mobile': '',
#    'title': 'بث مباشر مشاهدة مباراة منتخب مصر وسيراليون بتصفيات مونديال العالم 2026',
#    'seendate': '20250325T191500Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5014786',
#    'url_mobile': '',
#    'title': 'موعد مباراة الزمالك ضد سيراميكا فى كأس مصر والقنوات الناقلة',
#    'seendate': '20250327T081500Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/2411.html',
#    'url_mobile': '',
#    'title': 'ما هو لون حذاء نور النبوي .. سؤال الحلقة 25 من برنامج رامز إيلون مصر',
#    'seendate': '20250325T174500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-25-98efa81dc0.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/789.html',
#    'url_mobile': '',
#    'title': 'تحقيق الفوز الأول .. تشكيل الزمالك الرسمي ضد بتروجيت في كأس عاصمة مصر',
#    'seendate': '20250323T191500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-d6a142c077.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/114.html',
#    'url_mobile': '',
#    'title': 'موعد مباراة الزمالك وبتروجيت في كأس عاصمة مصر والقنوات الناقلة والتشكيل المتوقع',
#    'seendate': '20250323T060000Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-27348e7763.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5373576',
#    'url_mobile': '',
#    'title': 'بيطارد حسام حسن ، رقم مميز لمحمد صلاح بعد الفوز على إثيوبيا بتصفيات المونديال',
#    'seendate': '20250322T033000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5373616',
#    'url_mobile': '',
#    'title': 'موعد وصول منتخب مصر إلى القاهرة بعد الفوز أمام إثيوبيا',
#    'seendate': '20250322T033000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.chinapress.com.my/20250328/%E4%BB%8A%E5%B9%B4%E6%9D%A5%E7%AC%AC%E4%BA%8C%E5%BA%A7-%E5%9F%83%E5%8F%8A%E5%86%8D%E5%87%BA%E5%9C%9F%E6%B3%95%E8%80%81%E9%99%B5%E5%A2%93/',
#    'url_mobile': '',
#    'title': '今年来第二座 埃及再出土法老陵墓 | 中國報 China Press',
#    'seendate': '20250328T071500Z',
#    'socialimage': 'https://www.chinapress.com.my/wp-content/uploads/2025/03/20250329-Facebook-Chinapress-139-z.jpg',
#    'domain': 'chinapress.com.my',
#    'language': 'Chinese',
#    'sourcecountry': 'Malaysia'},
#   {'url': 'https://www.vetogate.com/5375705',
#    'url_mobile': '',
#    'title': 'تشكيل منتخب مصر المتوقع أمام سيراليون في تصفيات كأس العالم',
#    'seendate': '20250325T083000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.163.com/dy/article/JRDFFP6O0514R9P4.html',
#    'url_mobile': 'https://m.163.com/dy/article/JRDFFP6O0514R9P4.html',
#    'title': '行知读书会｜古埃及文明对永恒与重生的理解',
#    'seendate': '20250324T014500Z',
#    'socialimage': '',
#    'domain': '163.com',
#    'language': 'Chinese',
#    'sourcecountry': 'China'},
#   {'url': 'https://www.vetogate.com/5375797',
#    'url_mobile': '',
#    'title': 'مصر & سيراليون .. مواجهة مصيرية في تصفيات المونديال .. محمد صلاح يقود التشكيل المتوقع للمنتخب الوطني .. بوركينا فاسو تطارد الفراعنة .. وهذه سيناريوهات التأهل لكأس العالم 2026',
#    'seendate': '20250325T123000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.sdpnoticias.com/sorprendente/egipto-nuevo-descubrimiento-sobre-las-piramides-le-daria-un-nuevo-significado-a-su-construccion/',
#    'url_mobile': '',
#    'title': 'Egipto : Nuevo descubrimiento sobre las pirámides le daría otro significado a su construcción',
#    'seendate': '20250323T164500Z',
#    'socialimage': 'https://www.sdpnoticias.com/resizer/v2/GCEALBNX75OJHDJEBKXKF4SLYE.jpg?smart=true&auth=0092b96e902ece63e0fa7c3b9ebefdfcc50004781eeece3709f751cd732226c2',
#    'domain': 'sdpnoticias.com',
#    'language': 'Spanish',
#    'sourcecountry': 'Mexico'},
#   {'url': 'https://banyuwangi.viva.co.id/budaya/29690-7-tradisi-unik-lebaran-di-mesir-dari-kue-kahk-hingga-pesta-sungai-nil',
#    'url_mobile': 'https://banyuwangi.viva.co.id/amp/budaya/29690-7-tradisi-unik-lebaran-di-mesir-dari-kue-kahk-hingga-pesta-sungai-nil',
#    'title': '7 Tradisi Unik Lebaran di Mesir , Dari Kue Kahk Hingga Pesta Sungai Nil',
#    'seendate': '20250325T191500Z',
#    'socialimage': 'https://thumb.viva.id/vivabanyuwangi/665x374/2025/03/25/67e1f5dedc454-tradisi-unik-lebaran-di-mesir_banyuwangi.jpg',
#    'domain': 'banyuwangi.viva.co.id',
#    'language': 'Indonesian',
#    'sourcecountry': 'Indonesia'},
#   {'url': 'http://www.misr5.com/uncategorized/133.html',
#    'url_mobile': '',
#    'title': 'محمد الشهاوي : مصر حطمت آمال إسرائيل في الاحتفاظ بطابا ( فيديو ) ',
#    'seendate': '20250323T081500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-9df592d0d6.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5009940',
#    'url_mobile': '',
#    'title': 'سعر الذهب عيار 21 في الصاغة اليوم .. سعر جرام الذهب الآن في مصر',
#    'seendate': '20250323T083000Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5013912',
#    'url_mobile': '',
#    'title': 'موعد مباراة الزمالك وسيراميكا كليوباترا بكأس مصر والقنوات الناقلة',
#    'seendate': '20250326T120000Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5015869',
#    'url_mobile': '',
#    'title': 'أسعار البنزين والسولار اليوم الجمعة 28 مارس 2025 في محطات الوقود',
#    'seendate': '20250328T091500Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5373596',
#    'url_mobile': '',
#    'title': 'موعد مباراة منتخب مصر أمام سيراليون في تصفيات كأس العالم والقنوات الناقلة',
#    'seendate': '20250322T020000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5375986',
#    'url_mobile': '',
#    'title': 'أرقام حسام حسن مع منتخب مصر قبل مواجهة سيراليون الليلة',
#    'seendate': '20250325T130000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.dostor.org/5012312',
#    'url_mobile': '',
#    'title': 'موعد مباراة مصر وسيراليون فى تصفيات كأس العالم 2026 والقنوات الناقلة',
#    'seendate': '20250325T043000Z',
#    'socialimage': '',
#    'domain': 'dostor.org',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/2193.html',
#    'url_mobile': '',
#    'title': 'ماذا قدم منتخب مصر في التصفيات المؤهلة لكأس العالم قبل مواجهة سيراليون ؟ ',
#    'seendate': '20250325T130000Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-25-48ec763da0.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'http://www.misr5.com/uncategorized/1292.html',
#    'url_mobile': '',
#    'title': 'نجم نادي الزمالك .. من هو ضيف برنامج رامز إيلون مصر اليوم ؟ ',
#    'seendate': '20250324T121500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-24-f40daf0c5b.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.vetogate.com/5373866',
#    'url_mobile': '',
#    'title': 'أرقام محمد صلاح مع منتخب مصر في تصفيات كأس العالم 2026',
#    'seendate': '20250322T123000Z',
#    'socialimage': '',
#    'domain': 'vetogate.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'},
#   {'url': 'https://www.raialyoum.com/%D9%85%D9%80%D8%B5%D8%B7%D9%80%D9%81%D9%89-%D8%A8%D9%86-%D8%AE%D8%A7%D9%84%D8%AF-%D8%B4%D8%B0%D8%B1%D8%A7%D8%AA-%D8%A5%D8%B3%D8%AA%D8%B1%D8%A7%D8%AA%D9%8A%D8%AC%D9%8A%D8%A9-%D9%85%D8%B5%D8%B1/',
#    'url_mobile': '',
#    'title': 'مـصطـفى بن خالد : شذرات إستراتيجية .. مصر العروبة .. صمام الأمان العربي وحجر الأساس في حل الأزمات',
#    'seendate': '20250323T124500Z',
#    'socialimage': 'https://www.raialyoum.com/wp-content/uploads/2025/03/2025-03-23_11-54-35_013806.jpg',
#    'domain': 'raialyoum.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Israel'},
#   {'url': 'https://time.mk/c/adf6f55b12/najdena-grobnica-vo-egipet-stara-3-600-godini-arheolozi-go-otkrija-misteriozniot-faraon-sto-go-zaboravila-istorijata.html',
#    'url_mobile': '',
#    'title': 'Ново откритие ! Пронајдена гробница на неидентификуван фараон во Египет од пред 3 . 600 години',
#    'seendate': '20250328T164500Z',
#    'socialimage': '',
#    'domain': 'time.mk',
#    'language': 'Macedonian',
#    'sourcecountry': 'Macedonia'},
#   {'url': 'https://time.mk/c/adf6f55b12/novo-otkritie-pronajdena-grobnica-na-neidentifikuvan-faraon-vo-egipet-od-pred-3-600-godini.html',
#    'url_mobile': '',
#    'title': 'Ново откритие ! Пронајдена гробница на неидентификуван фараон во Египет од пред 3 . 600 години',
#    'seendate': '20250328T141500Z',
#    'socialimage': '',
#    'domain': 'time.mk',
#    'language': 'Macedonian',
#    'sourcecountry': 'Macedonia'},
#   {'url': 'http://www.misr5.com/uncategorized/794.html',
#    'url_mobile': '',
#    'title': 'التشكيل الرسمي لمباراة الإسماعيلي أمام بيراميدز في كأس عاصمة مصر',
#    'seendate': '20250323T191500Z',
#    'socialimage': 'http://www.misr5.com/temp/resized/medium_2025-03-23-d90ef01381.jpg',
#    'domain': 'misr5.com',
#    'language': 'Arabic',
#    'sourcecountry': 'Egypt'}]}

# %% [markdown]
# Create GDELT articles to summary transformation.

# %%
def get_summary(user_prompt, gdelt_articles):

    # Initialize Cohere client
    with open("key.txt") as f:
        COHERE_API_KEY = f.read()
    cohere_client = cohere.ClientV2(COHERE_API_KEY)

    # Define the system parameters
    system_prompt = f"""
    The user will give you a list of articles from GDELT including the URL, Date and Title.
    The user has previously asked:
    {user_prompt}
    Respond with a brief summary responding to the users previous question.
    Base your response only on the information from the given articles.
    Recommend the user between 1 and 5 most relevant articles including the URLs and titles. Translate the titles to English if necessary.
    Respond only with the summary and recommended articles.
    """

    # Check if model input is string
    if not isinstance(gdelt_articles, str):
        gdelt_articles = str(gdelt_articles)

    # Get the model response
    raw_response = cohere_client.chat(
        messages = [
        {
            'role': 'system',
            'content': system_prompt  
        }, 
        {
            'role': 'user',
            'content': gdelt_articles
        }
        ],
        model='command-r-plus'
    )

    # Check if the response is valid and return the response
    try:
        response = raw_response.message.content[0].text
    except Exception:
        response = raw_response
    return response

# %% [markdown]
# Test transformation.

# %%
test_summary = get_summary(test_prompt, test_articles)
test_summary
# Out:
# "Egypt is in the spotlight for its sports, politics, and ancient history. The Egyptian national football team faced Sierra Leone in a crucial World Cup qualifier, with Mohamed Salah leading the lineup. Egypt's parliament has been busy, referring international agreements and bills to committees. In other news, a mysterious ancient pharaoh's tomb was discovered, offering insights into Egypt's rich past. \n\nRecommended articles: \n\n1. 'مصر ضد سيراليون .. موعد المباراة والقنوات الناقلة والتشكيل وترتيب المجموعة' - misr5.com - Arabic\n2. 'مشاهدة مباراة مصر وسيراليون في تصفيات مونديال 2026 .. بث مباشر الآن ( فيديو ) ' - dostor.org - Arabic\n3. 'مصر & سيراليون .. مواجهة مصيرية في تصفيات المونديال .. محمد صلاح يقود التشكيل المتوقع للمنتخب الوطني .. بوركينا فاسو تطارد الفراعنة .. وهذه سيناريوهات التأهل لكأس العالم 2026' - vetogate.com - Arabic\n4. 'مجلس النواب يُحيل تعديلات أحكام قانون المرور للجان المختصة' - shorouknews.com - Arabic\n5. 'جبالي يحيل قرارات باتفاقيات دولية إلى لجنة الشئون الدستورية والتشريعية' - misr5.com - Arabic"

# %% [markdown]
# Create PDF generation function for summary download.

# %%
def generate_pdf(user_prompt, summary):
    
    # Initialize PDF
    pdf = FPDF()
    pdf.add_page()
    
    # Set up PDF header
    pdf.set_font("Helvetica", style="B", size=16)
    pdf.cell(0, 10, "World Events News Summarizer", new_x=XPos.LMARGIN, new_y=YPos.NEXT, align="C")
    pdf.ln(10)
    
    # Add user prompt
    pdf.set_font("Helvetica", style="I", size=12)
    pdf.multi_cell(0, 10, user_prompt.encode('latin-1', 'replace').decode('latin-1'))
    pdf.ln(10)

    # Add summary
    pdf.set_font("Helvetica", size=12)
    pdf.multi_cell(0, 10, summary.encode('latin-1', 'replace').decode('latin-1'))
    
    # Return the PDF as a bytes buffer
    pdf_buffer = bytes(pdf.output())
    return pdf_buffer

# %% [markdown]
# Test generation.

# %%
test_pdf = generate_pdf(test_prompt, test_summary)
test_pdf
# Out:
# b'%PDF-1.3\n1 0 obj\n<<\n/Count 1\n/Kids [3 0 R]\n/MediaBox [0 0 595.28 841.89]\n/Type /Pages\n>>\nendobj\n2 0 obj\n<<\n/OpenAction [3 0 R /FitH null]\n/PageLayout /OneColumn\n/Pages 1 0 R\n/Type /Catalog\n>>\nendobj\n3 0 obj\n<<\n/Contents 4 0 R\n/Parent 1 0 R\n/Resources 8 0 R\n/Type /Page\n>>\nendobj\n4 0 obj\n<<\n/Filter /FlateDecode\n/Length 734\n>>\nstream\nx\x9c\x85\x94Qo\xda0\x10\xc7\xdf\xf7)\xeeiP\xa9u\x13\'!\xc9^\xd06\xb5\xd2\xa6m\xd2V\xa4\xbd\xf4\xc5$\x86xK\xec\xd4v\x8a\xd8\xa7\xdf9\x86@h\xd6!\x10\xc6\xb1\xff\xf7\xbb\xff\xddA\xe1\xf3\x9b\x80$)\xec\xde|X\xc1\xed}\x08\xe1\x82\x04\x01\xac6p\xb7r[a\x9a\x90(\x834\x8f\xdd\xa9U\t\xf3\x9fJ\xd7%\xdc=si\r|\xe3;\x03\x0f]\xd30-\xfep}\x05\xab_\x87\x8b\xb7\xf7\x14B:\xd2\x8aB\x12\xa2T\x94\x93 \xf3R\x15\xb33\x03\x15k[.\x85\xdc\x82\x90p\xb7\xdd\xb7\x16\xb4\xd8V\x16\xa4\xda-G\x92\xd1H\xf2\t\x06\xd1EF\x1d&\x8a\x86d\x91\xe5\xb0\xda\xc1\xdc+\t\xe3Tm\xc5\xc1\xb4\xca\xd6\xbd\xeeFi\x10H\x8f;\xda\x9akhU-\xac(p\xc5d\x89\x9fB`rP\tc\x95\xde\x13X\xe1\xe5^L0\t\x92Y\xa1$\xabQD\xd95\xab\xeb\x03 |\x1f\xf1$1\tb\xcf\x13,<\x8f\xe5\xac\x81\r+x\t\x0f\x82k\xcd\xe0\x0bW\x92;<\x06\x85\xee\n\x81\xaa\xde\xdd\x8f]\x0bO\x1d\xab\xc5\x06\x0f^\xc3N\xd8\n\xbe\xaa\x8a5\xee.\xabY\x055g\xa5s\xcc%V\x0b\xc9\xbb\x96L\x83\xd0\x84\xb8\xf8%\xa0qQ|2\x06}o\x99\xae\x05j\xba\\\x99\x815\xe7\x12\xd6\x9d\xd9_\x83\xe6\x1b\x04\xf4\x15\xb1\\\x0f9\xb3\xad\xe6\xbc\xe9+\xef\x9cZ\x8b\xba6`\x15\x14\xaai\x84\xb5\x9c\x1b\x02\x9f\xe4$H\x92\xa7$J\x1c\x88\xeb\xb7\xa8\x07QH\xafAb\x0f\xa1\xf3\xd0\xec\r\xc6\x12\xaa3C\t\xda\x8ai\xa6\xaa\x99\x0b\xd2\xaca\x87\x94\xa50\x85z\xe6\x9a\x97\xd7\xa06\x88\xe9)\x8d+\xac+5\xd2\x1c\xf3\xd3\xa2\xa8N,\'\x92E\xde\xf7\x106`\xcb\x8c%p\xd6b\x87\x13\xd8eQ\xd8\x9f\xf8\xc1]n\\\x96\xe8<\xd3\xd8$57\xef\x86\x1bg\xf9\xc5\t\x1a\xdd\xdf\x89I\x9c\xa7}~!\x81\xd9r\xb9\x84\xfe\xed_@H\xbf>m\\..7\x86\xdf3\xb8\x99\xc8&\xa6)\xa1~2\x1batB\x90\x17n\xe0\xbdfkQLpFyFr\xea\x1b"w6 \'\xf5\x9c\xe3\x98C\xdc3\xfe\x81\x91\x06t\xe1S\x81\xd3\x03x\x9c\x1f~=^\xc14m\x94\x06\xc7\xff\x91R\xb9\xf1"Jo_\xc5\x8d)\xa1\xd1\xa1m\x1c7\xe2F\x07[\xdf\xbep\xf5\x1c\xf4\xd2\xbe\xb1\xf5\xa3"\x1c\xbf\'\x1b7\n#\x92e\x9e \x08\x17=\xc1E\x85\x86\xe8\xe7\xb2\xff.\xf9\x98\xed\xb8v\x96\xce&,\xa3YB\x92\xde\x81\xf9\r<s\xab\xb6\xcc\xf2\xc9*\x9f\xae$)\t\xfb\xa1\x9f\xc7\x87\xd2\x8e\xdc\x18\xe7\r/\x90\x86\x03XD0\x95\xd2\xaa\xfb\xed\xa6\xf4\x7f\xbdEiF\xb2\xd8[\x15%~\x06\x92co\xc1\x8b(\xe3x\xaf=\x1f`\xceZ|\xca\xaa \xc0\xd9\xeb\xf3\x1e3\xfe\x05\xa5\x15\xd6\xf8\nendstream\nendobj\n5 0 obj\n<<\n/BaseFont /Helvetica-Bold\n/Encoding /WinAnsiEncoding\n/Subtype /Type1\n/Type /Font\n>>\nendobj\n6 0 obj\n<<\n/BaseFont /Helvetica-Oblique\n/Encoding /WinAnsiEncoding\n/Subtype /Type1\n/Type /Font\n>>\nendobj\n7 0 obj\n<<\n/BaseFont /Helvetica\n/Encoding /WinAnsiEncoding\n/Subtype /Type1\n/Type /Font\n>>\nendobj\n8 0 obj\n<<\n/Font <</F1 5 0 R\n/F2 6 0 R\n/F3 7 0 R>>\n/ProcSet [/PDF /Text /ImageB /ImageC /ImageI]\n>>\nendobj\n9 0 obj\n<<\n/CreationDate (D:20250330133032Z)\n>>\nendobj\nxref\n0 10\n0000000000 65535 f \n0000000009 00000 n \n0000000096 00000 n \n0000000199 00000 n \n0000000279 00000 n \n0000001085 00000 n \n0000001187 00000 n \n0000001292 00000 n \n0000001389 00000 n \n0000001496 00000 n \ntrailer\n<<\n/Size 10\n/Root 2 0 R\n/Info 9 0 R\n/ID [<BDA090CC76E1098F09E8CCAA23861E32><BDA090CC76E1098F09E8CCAA23861E32>]\n>>\nstartxref\n1551\n%%EOF\n'

# %%
with open("test.pdf", "wb") as f:
    f.write(test_pdf)
